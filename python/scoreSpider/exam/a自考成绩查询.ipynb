# %%
import requests
url = "https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430110&ksmx=%E5%88%98%E9%87%91%E6%9E%97"
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
} 
resp = requests.get(url,headers=headers)
html = resp.content.decode('utf-8')

# %%
import requests
url = "https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430110&ksmx=%E5%88%98%E9%87%91%E6%9E%97"
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
} 
resp1 = requests.get(url,headers=headers)
resp1
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, "html.parser") 
# soup

# %%
table = soup.find_all(name='td')
j = 1
datas = []
for i in table:
    datas.append(i.string)
# print(datas)
for i in range(2,len(datas),6):
    if i%2==0:
        print(datas[i],":",datas[i+1])                   # 2 3     8 9
# Out:
# 英语（二） : 53
# 中国近现代史纲要 : 85
# JAVA程序设计 : 82
# 人工智能导论 : 85
# 网络安全技术 : 90
# 英语（二） : 55
# 马克思主义基本原理概论 : 82
# 软件工程 : 93
# 计算机组成原理 : 100
# C++程序设计（实践） : 94

# %%
table = soup.find_all(name='td')
j = 1
datas = []
s = {}
for i in table:
    datas.append(str(i.string))
# print(datas)
for i in range(2,len(datas)):
    if len(datas[i])>1 and len(datas[i])<=3:
        if eval(datas[i])<=100 or eval(datas[i])>=0 or datas[i]=="免考":
#             print(datas[i-1],":",datas[i])
            s[datas[i-1]] = datas[i]
print(s)
# Out:
# {'英语（二）': '55', '中国近现代史纲要': '85', 'JAVA程序设计': '82', '人工智能导论': '85', '网络安全技术': '90', '马克思主义基本原理概论': '82', '软件工程': '93', '计算机组成原理': '100', 'C++程序设计（实践）': '94'}

# %%
table = soup.find_all(name='td')
j = 1
datas = []
s = {}
for i in table:
    datas.append(str(i.string))
# print(datas)
for i in range(2,len(datas)):
    if len(datas[i])>1 and len(datas[i])<=3:
#         if eval(datas[i])<=100 or eval(datas[i])>=0 or datas[i]=="免考":
        print(datas[i-1],":",datas[i])
        s[datas[i-1]] = datas[i]
print(s)
# Out:
# 英语（二） : 53
# 中国近现代史纲要 : 85
# JAVA程序设计 : 82
# 人工智能导论 : 85
# 网络安全技术 : 90
# 英语（二） : 55
# 马克思主义基本原理概论 : 82
# 软件工程 : 93
# 计算机组成原理 : 100
# C++程序设计（实践） : 94
# {'英语（二）': '55', '中国近现代史纲要': '85', 'JAVA程序设计': '82', '人工智能导论': '85', '网络安全技术': '90', '马克思主义基本原理概论': '82', '软件工程': '93', '计算机组成原理': '100', 'C++程序设计（实践）': '94'}

# %%
import pandas as pd
path = "./zkz.xlsx"
df = pd.read_excel(path,dtype=str)
# 获取需要的 姓名、准考证  信息数据
students = df[["姓名","准考证号"]]

# %%
a = students
name = []
ids = []
for i in a:
    name.append(a["姓名"])
    ids.append(a["准考证号"])
a[0] = name[0]
a[1] = ids[0]
print(a[1])
# Out:
# 0      018622430856
# 1      018622430823
# 2      018622430822
# 3      018622430820
# 4      018622430819
#            ...
# 200    018622430059
# 201    018622430058
# 202    018622430057
# 203    018622430056
# 204    018622430055
# Name: 1, Length: 205, dtype: object

# %%
import requests
from bs4 import BeautifulSoup

def getDatas(id_,name):
    print("准考证号:{},姓名:{}".format(id_,name))
    url = "https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh={}&ksmx={}".format(id_,name)
    print(url)
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
    }
    resp = requests.get(url,headers=headers)
    html = resp.content.decode('utf-8')
    soup = BeautifulSoup(html, "html.parser") 
    table = soup.find_all(name='td')
    j = 1
    datas = []
    scores = {}
    scores["准考证"] = id_
    scores["姓名"] = name
    for i in table:
        if i.string != "理论课程":
            datas.append(i.string)
    for i in range(2,len(datas)):
        if datas[i]!=None:
            if len(datas[i])>1 and len(datas[i])<=3:
                if eval(datas[i])<=100 or eval(datas[i])>=0:
#                     print(datas[i-1],":",datas[i])
                    scores[datas[i-1]] = datas[i]
                    
            if "免" in datas[i] and datas[i-1]!=None:
#                 print(datas[i-1],":","免考")
                scores[datas[i-1]] = "免考"
    print(scores)
    print("=======================================================================================================================================")
    return scores

# %%
getDatas(a[1][0],a[0][0])
# Out:
# 准考证号:018622430856,姓名:王颢杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430856&ksmx=王颢杰
# {'准考证': '018622430856', '姓名': '王颢杰', 'JAVA程序设计': '59', '人工智能导论': '58', '网络安全技术': '80', '英语（二）': '26', '马克思主义基本原理概论': '48', '软件工程': '90', '计算机组成原理': '62', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# {'准考证': '018622430856',
#  '姓名': '王颢杰',
#  'JAVA程序设计': '59',
#  '人工智能导论': '58',
#  '网络安全技术': '80',
#  '英语（二）': '26',
#  '马克思主义基本原理概论': '48',
#  '软件工程': '90',
#  '计算机组成原理': '62',
#  'C++程序设计（实践）': '70'}

# %%
scores_list = []
for i in range(0,len(students)):
    scores_dic = getDatas(a[1][i],a[0][i])
    scores_list.append(scores_dic)
# Out:
# 准考证号:018622430856,姓名:王颢杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430856&ksmx=王颢杰
# {'准考证': '018622430856', '姓名': '王颢杰', 'JAVA程序设计': '59', '人工智能导论': '58', '网络安全技术': '80', '英语（二）': '26', '马克思主义基本原理概论': '48', '软件工程': '90', '计算机组成原理': '62', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430823,姓名:罗瑞清
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430823&ksmx=罗瑞清
# {'准考证': '018622430823', '姓名': '罗瑞清', '英语（二）': '10', '中国近现代史纲要': '68', '计算机组成原理': '28', 'JAVA程序设计': '57', '人工智能导论': '70', '网络安全技术': '66', '马克思主义基本原理概论': '66', '软件工程': '72', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430822,姓名:王晨依
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430822&ksmx=王晨依
# {'准考证': '018622430822', '姓名': '王晨依', '英语（二）': '44', '中国近现代史纲要': '74', 'JAVA程序设计': '77', '人工智能导论': '88', '网络安全技术': '87', '马克思主义基本原理概论': '68', '软件工程': '93', '计算机组成原理': '95', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430820,姓名:李昊
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430820&ksmx=李昊
# {'准考证': '018622430820', '姓名': '李昊', 'JAVA程序设计': '69', '人工智能导论': '76', '网络安全技术': '85', '英语（二）': '60', '马克思主义基本原理概论': '74', '中国近现代史纲要': '61', '软件工程': '93', '计算机组成原理': '70', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430819,姓名:黄佳义
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430819&ksmx=黄佳义
# {'准考证': '018622430819', '姓名': '黄佳义', '英语（二）': '37', '中国近现代史纲要': '81', 'JAVA程序设计': '74', '人工智能导论': '84', '网络安全技术': '84', '马克思主义基本原理概论': '73', '软件工程': '94', '计算机组成原理': '91', 'C++程序设计（实践）': '78'}
# =======================================================================================================================================
# 准考证号:018622430818,姓名:邵凯旋
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430818&ksmx=邵凯旋
# {'准考证': '018622430818', '姓名': '邵凯旋', '英语（二）': '37', '中国近现代史纲要': '72', 'JAVA程序设计': '70', '人工智能导论': '75', '网络安全技术': '76', '马克思主义基本原理概论': '68', '软件工程': '90', '计算机组成原理': '83', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430817,姓名:米玛措姆
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430817&ksmx=米玛措姆
# {'准考证': '018622430817', '姓名': '米玛措姆', '英语（二）': '38', '中国近现代史纲要': '73', '马克思主义基本原理概论': '56', '软件工程': '78', 'JAVA程序设计': '84', '人工智能导论': '87', '网络安全技术': '80', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430816,姓名:沈飞
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430816&ksmx=沈飞
# {'准考证': '018622430816', '姓名': '沈飞', '英语（二）': '42', '中国近现代史纲要': '80', 'JAVA程序设计': '88', '人工智能导论': '90', '网络安全技术': '81', '马克思主义基本原理概论': '72', '软件工程': '97', '计算机组成原理': '99', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430815,姓名:宋京鹏
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430815&ksmx=宋京鹏
# {'准考证': '018622430815', '姓名': '宋京鹏', '中国近现代史纲要': '84', 'JAVA程序设计': '78', '人工智能导论': '78', '网络安全技术': '87', '英语（二）': '60', '马克思主义基本原理概论': '82', '软件工程': '98', '计算机组成原理': '99', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430814,姓名:段文龙
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430814&ksmx=段文龙
# {'准考证': '018622430814', '姓名': '段文龙', '英语（二）': '31', '中国近现代史纲要': '82', '软件工程': '94', 'JAVA程序设计': '80', '人工智能导论': '75', '网络安全技术': '84', '马克思主义基本原理概论': '68', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430812,姓名:张锐
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430812&ksmx=张锐
# {'准考证': '018622430812', '姓名': '张锐', '英语（二）': '51', '中国近现代史纲要': '80', '软件工程': '100', 'JAVA程序设计': '91', '人工智能导论': '90', '网络安全技术': '85', '马克思主义基本原理概论': '79', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430248,姓名:丁玥玥
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430248&ksmx=丁玥玥
# {'准考证': '018622430248', '姓名': '丁玥玥', 'JAVA程序设计': '49', '人工智能导论': '65', '网络安全技术': '78', '英语（二）': '50', '马克思主义基本原理概论': '71', '软件工程': '91', '计算机组成原理': '81', 'C++程序设计（实践）': '93'}
# =======================================================================================================================================
# 准考证号:018622430247,姓名:刘雅轩
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430247&ksmx=刘雅轩
# {'准考证': '018622430247', '姓名': '刘雅轩', '英语（二）': '43', '中国近现代史纲要': '77', 'JAVA程序设计': '86', '人工智能导论': '96', '网络安全技术': '87', '马克思主义基本原理概论': '77', '软件工程': '99', '计算机组成原理': '93', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430246,姓名:刘泓妙
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430246&ksmx=刘泓妙
# {'准考证': '018622430246', '姓名': '刘泓妙', '英语（二）': '61', '中国近现代史纲要': '80', 'JAVA程序设计': '84', '人工智能导论': '79', '网络安全技术': '83', '马克思主义基本原理概论': '73', '软件工程': '99', '计算机组成原理': '100', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430245,姓名:孙羽婷
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430245&ksmx=孙羽婷
# {'准考证': '018622430245', '姓名': '孙羽婷', '英语（二）': '61', '中国近现代史纲要': '82', 'JAVA程序设计': '79', '人工智能导论': '93', '网络安全技术': '83', '马克思主义基本原理概论': '82', '软件工程': '99', '计算机组成原理': '96', 'C++程序设计（实践）': '94'}
# =======================================================================================================================================
# 准考证号:018622430244,姓名:许晨昕
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430244&ksmx=许晨昕
# {'准考证': '018622430244', '姓名': '许晨昕', '英语（二）': '免考', '中国近现代史纲要': '85', '马克思主义基本原理概论': '55', 'JAVA程序设计': '87', '人工智能导论': '95', '网络安全技术': '77', '软件工程': '88', '计算机组成原理': '85', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430243,姓名:赵婧雯
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430243&ksmx=赵婧雯
# {'准考证': '018622430243', '姓名': '赵婧雯', '英语（二）': '50', '中国近现代史纲要': '79', 'JAVA程序设计': '88', '人工智能导论': '100', '网络安全技术': '88', '马克思主义基本原理概论': '68', '软件工程': '93', '计算机组成原理': '94', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430242,姓名:余强
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430242&ksmx=余强
# {'准考证': '018622430242', '姓名': '余强', '英语（二）': '75', '中国近现代史纲要': '77', 'JAVA程序设计': '82', '人工智能导论': '93', '网络安全技术': '80', '马克思主义基本原理概论': '68', '软件工程': '98', '计算机组成原理': '93', 'C++程序设计（实践）': '78'}
# =======================================================================================================================================
# 准考证号:018622430241,姓名:孙若雨
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430241&ksmx=孙若雨
# {'准考证': '018622430241', '姓名': '孙若雨', '英语（二）': '52', '中国近现代史纲要': '79', 'JAVA程序设计': '91', '人工智能导论': '92', '网络安全技术': '86', '马克思主义基本原理概论': '76', '软件工程': '98', '计算机组成原理': '92', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430240,姓名:陈晨
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430240&ksmx=陈晨
# {'准考证': '018622430240', '姓名': '陈晨', '英语（二）': '48', '中国近现代史纲要': '79', 'JAVA程序设计': '65', '人工智能导论': '85', '网络安全技术': '85', '马克思主义基本原理概论': '72', '软件工程': '91', '计算机组成原理': '95', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430239,姓名:詹成康
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430239&ksmx=詹成康
# {'准考证': '018622430239', '姓名': '詹成康', '中国近现代史纲要': '83', 'JAVA程序设计': '83', '人工智能导论': '100', '网络安全技术': '90', '英语（二）': '60', '马克思主义基本原理概论': '74', '软件工程': '99', '计算机组成原理': '100', 'C++程序设计（实践）': '72'}
# =======================================================================================================================================
# 准考证号:018622430238,姓名:李徽
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430238&ksmx=李徽
# {'准考证': '018622430238', '姓名': '李徽', '英语（二）': '44', '中国近现代史纲要': '80', 'JAVA程序设计': '83', '人工智能导论': '83', '网络安全技术': '85', '马克思主义基本原理概论': '70', '软件工程': '94', '计算机组成原理': '97', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430237,姓名:万晨鹏
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430237&ksmx=万晨鹏
# {'准考证': '018622430237', '姓名': '万晨鹏', '英语（二）': '免考', '中国近现代史纲要': '81', 'JAVA程序设计': '78', '人工智能导论': '78', '网络安全技术': '82', '马克思主义基本原理概论': '72', '软件工程': '86', '计算机组成原理': '86', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430236,姓名:王锦轩
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430236&ksmx=王锦轩
# {'准考证': '018622430236', '姓名': '王锦轩', '英语（二）': '免考', '中国近现代史纲要': '79', 'JAVA程序设计': '65', '人工智能导论': '82', '网络安全技术': '74', '马克思主义基本原理概论': '61', '软件工程': '98', '计算机组成原理': '96', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430235,姓名:林芝云
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430235&ksmx=林芝云
# {'准考证': '018622430235', '姓名': '林芝云', '中国近现代史纲要': '82', 'JAVA程序设计': '94', '人工智能导论': '99', '网络安全技术': '90', '英语（二）': '63', '马克思主义基本原理概论': '81', '软件工程': '94', '计算机组成原理': '100', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430234,姓名:马建国
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430234&ksmx=马建国
# {'准考证': '018622430234', '姓名': '马建国', '英语（二）': '44', '中国近现代史纲要': '80', 'JAVA程序设计': '85', '人工智能导论': '89', '网络安全技术': '87', '马克思主义基本原理概论': '81', '软件工程': '93', '计算机组成原理': '97', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430233,姓名:伍梦妍
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430233&ksmx=伍梦妍
# {'准考证': '018622430233', '姓名': '伍梦妍', '中国近现代史纲要': '81', '马克思主义基本原理概论': '51', 'JAVA程序设计': '68', '人工智能导论': '81', '网络安全技术': '82', '英语（二）': '63', '软件工程': '91', '计算机组成原理': '60', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430232,姓名:张浩伟
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430232&ksmx=张浩伟
# {'准考证': '018622430232', '姓名': '张浩伟', '英语（二）': '59', '中国近现代史纲要': '85', 'JAVA程序设计': '87', '人工智能导论': '72', '网络安全技术': '81', '马克思主义基本原理概论': '78', '软件工程': '95', '计算机组成原理': '96', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430231,姓名:王鑫
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430231&ksmx=王鑫
# {'准考证': '018622430231', '姓名': '王鑫', '英语（二）': '36', '中国近现代史纲要': '76', 'JAVA程序设计': '63', '人工智能导论': '78', '网络安全技术': '82', '马克思主义基本原理概论': '65', '软件工程': '98', '计算机组成原理': '89', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430230,姓名:时婷
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430230&ksmx=时婷
# {'准考证': '018622430230', '姓名': '时婷', '英语（二）': '44', '中国近现代史纲要': '79', 'JAVA程序设计': '77', '人工智能导论': '93', '网络安全技术': '90', '马克思主义基本原理概论': '71', '软件工程': '99', '计算机组成原理': '100', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430229,姓名:屠隽超
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430229&ksmx=屠隽超
# {'准考证': '018622430229', '姓名': '屠隽超', '英语（二）': '51', '中国近现代史纲要': '79', 'JAVA程序设计': '74', '人工智能导论': '82', '网络安全技术': '83', '马克思主义基本原理概论': '70', '软件工程': '92', '计算机组成原理': '95', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430228,姓名:张珺雯
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430228&ksmx=张珺雯
# {'准考证': '018622430228', '姓名': '张珺雯', '中国近现代史纲要': '78', 'JAVA程序设计': '81', '人工智能导论': '88', '网络安全技术': '89', '英语（二）': '67', '马克思主义基本原理概论': '65', '软件工程': '93', '计算机组成原理': '81', 'C++程序设计（实践）': '92'}
# =======================================================================================================================================
# 准考证号:018622430227,姓名:王雨祥
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430227&ksmx=王雨祥
# {'准考证': '018622430227', '姓名': '王雨祥', '英语（二）': '49', '中国近现代史纲要': '78', 'JAVA程序设计': '88', '人工智能导论': '91', '网络安全技术': '88', '马克思主义基本原理概论': '80', '软件工程': '99', '计算机组成原理': '93', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430226,姓名:刘渃怡
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430226&ksmx=刘渃怡
# {'准考证': '018622430226', '姓名': '刘渃怡', '英语（二）': '49', '中国近现代史纲要': '77', 'JAVA程序设计': '88', '人工智能导论': '90', '网络安全技术': '89', '马克思主义基本原理概论': '72', '软件工程': '90', '计算机组成原理': '85', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430225,姓名:吴意
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430225&ksmx=吴意
# {'准考证': '018622430225', '姓名': '吴意', '英语（二）': '36', 'JAVA程序设计': '56', '人工智能导论': '58', '网络安全技术': '80', '马克思主义基本原理概论': '50', '软件工程': '86', '计算机组成原理': '76', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430224,姓名:姚传贞
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430224&ksmx=姚传贞
# {'准考证': '018622430224', '姓名': '姚传贞', '英语（二）': '54', '中国近现代史纲要': '83', 'JAVA程序设计': '88', '人工智能导论': '97', '网络安全技术': '91', '马克思主义基本原理概论': '76', '软件工程': '99', '计算机组成原理': '100', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430223,姓名:张阳
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430223&ksmx=张阳
# {'准考证': '018622430223', '姓名': '张阳', '英语（二）': '53', '中国近现代史纲要': '68', 'JAVA程序设计': '78', '人工智能导论': '74', '网络安全技术': '75', '马克思主义基本原理概论': '66', '软件工程': '89', '计算机组成原理': '60', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430222,姓名:夏毛龙
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430222&ksmx=夏毛龙
# {'准考证': '018622430222', '姓名': '夏毛龙', '英语（二）': '30', '中国近现代史纲要': '76', 'JAVA程序设计': '62', '人工智能导论': '82', '网络安全技术': '83', '马克思主义基本原理概论': '63', '软件工程': '87', '计算机组成原理': '99', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430221,姓名:唐蒋豪
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430221&ksmx=唐蒋豪
# {'准考证': '018622430221', '姓名': '唐蒋豪', '中国近现代史纲要': '78', '软件工程': '90', 'JAVA程序设计': '70', '人工智能导论': '80', '网络安全技术': '77', '英语（二）': '61', '马克思主义基本原理概论': '73', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430220,姓名:周沛阳
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430220&ksmx=周沛阳
# {'准考证': '018622430220', '姓名': '周沛阳', '英语（二）': '46', '中国近现代史纲要': '73', 'JAVA程序设计': '59', '人工智能导论': '81', '网络安全技术': '89', '马克思主义基本原理概论': '69', '软件工程': '82', '计算机组成原理': '79', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430219,姓名:左志文
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430219&ksmx=左志文
# {'准考证': '018622430219', '姓名': '左志文', '英语（二）': '41', '中国近现代史纲要': '85', 'JAVA程序设计': '87', '人工智能导论': '89', '网络安全技术': '89', '马克思主义基本原理概论': '69', '软件工程': '94', '计算机组成原理': '100', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430218,姓名:何印
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430218&ksmx=何印
# {'准考证': '018622430218', '姓名': '何印', '英语（二）': '17', '中国近现代史纲要': '80', 'JAVA程序设计': '80', '人工智能导论': '86', '网络安全技术': '82', '马克思主义基本原理概论': '71', '软件工程': '98', '计算机组成原理': '97', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430217,姓名:宋飞宇
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430217&ksmx=宋飞宇
# {'准考证': '018622430217', '姓名': '宋飞宇', '英语（二）': '71', '中国近现代史纲要': '85', 'JAVA程序设计': '78', '人工智能导论': '100', '网络安全技术': '87', '马克思主义基本原理概论': '78', '软件工程': '86', '计算机组成原理': '89', 'C++程序设计（实践）': '74'}
# =======================================================================================================================================
# 准考证号:018622430216,姓名:虎鹏
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430216&ksmx=虎鹏
# {'准考证': '018622430216', '姓名': '虎鹏', '英语（二）': '42', '中国近现代史纲要': '77', 'JAVA程序设计': '82', '人工智能导论': '78', '网络安全技术': '86', '马克思主义基本原理概论': '63', '软件工程': '98', '计算机组成原理': '86', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430215,姓名:杨木易
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430215&ksmx=杨木易
# {'准考证': '018622430215', '姓名': '杨木易', '中国近现代史纲要': '70', 'JAVA程序设计': '87', '人工智能导论': '75', '网络安全技术': '83', '英语（二）': '61', '马克思主义基本原理概论': '71', '软件工程': '98', '计算机组成原理': '97', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430214,姓名:龚骁宇
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430214&ksmx=龚骁宇
# {'准考证': '018622430214', '姓名': '龚骁宇', '英语（二）': '35', '中国近现代史纲要': '78', 'JAVA程序设计': '58', '人工智能导论': '66', '网络安全技术': '81', '马克思主义基本原理概论': '63', '软件工程': '97', '计算机组成原理': '85', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430213,姓名:曹喜艳
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430213&ksmx=曹喜艳
# {'准考证': '018622430213', '姓名': '曹喜艳', '英语（二）': '71', '中国近现代史纲要': '76', 'JAVA程序设计': '76', '人工智能导论': '67', '网络安全技术': '85', '马克思主义基本原理概论': '63', '软件工程': '90', '计算机组成原理': '78', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430212,姓名:郭宇翔
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430212&ksmx=郭宇翔
# {'准考证': '018622430212', '姓名': '郭宇翔', '英语（二）': '48', '中国近现代史纲要': '70', '软件工程': '99', 'JAVA程序设计': '60', '人工智能导论': '76', '网络安全技术': '79', '马克思主义基本原理概论': '72', 'C++程序设计（实践）': '92'}
# =======================================================================================================================================
# 准考证号:018622430211,姓名:陈新洋
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430211&ksmx=陈新洋
# {'准考证': '018622430211', '姓名': '陈新洋', '英语（二）': '46', '中国近现代史纲要': '80', 'JAVA程序设计': '80', '人工智能导论': '90', '网络安全技术': '86', '马克思主义基本原理概论': '70', '软件工程': '94', '计算机组成原理': '77', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430210,姓名:单浩宇
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430210&ksmx=单浩宇
# {'准考证': '018622430210', '姓名': '单浩宇', '中国近现代史纲要': '82', 'JAVA程序设计': '84', '人工智能导论': '100', '网络安全技术': '81', '英语（二）': '65', '马克思主义基本原理概论': '74', '软件工程': '76', '计算机组成原理': '98', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430209,姓名:陆雨杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430209&ksmx=陆雨杰
# {'准考证': '018622430209', '姓名': '陆雨杰', '英语（二）': '免考', '中国近现代史纲要': '74', '软件工程': '85', 'JAVA程序设计': '69', '人工智能导论': '81', '网络安全技术': '78', '马克思主义基本原理概论': '66', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430208,姓名:戴江枫
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430208&ksmx=戴江枫
# {'准考证': '018622430208', '姓名': '戴江枫', '英语（二）': '57', '中国近现代史纲要': '82', 'JAVA程序设计': '87', '人工智能导论': '76', '网络安全技术': '79', '马克思主义基本原理概论': '64', '软件工程': '89', '计算机组成原理': '94', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430207,姓名:蒋文杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430207&ksmx=蒋文杰
# {'准考证': '018622430207', '姓名': '蒋文杰', '中国近现代史纲要': '81', 'JAVA程序设计': '72', '人工智能导论': '73', '网络安全技术': '78', '英语（二）': '64', '马克思主义基本原理概论': '70', '软件工程': '99', '计算机组成原理': '70', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430206,姓名:戴炜
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430206&ksmx=戴炜
# {'准考证': '018622430206', '姓名': '戴炜'}
# =======================================================================================================================================
# 准考证号:018622430205,姓名:徐才杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430205&ksmx=徐才杰
# {'准考证': '018622430205', '姓名': '徐才杰', '英语（二）': '62', '中国近现代史纲要': '71', 'JAVA程序设计': '81', '人工智能导论': '74', '网络安全技术': '78', '马克思主义基本原理概论': '69', '软件工程': '99', '计算机组成原理': '69', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430204,姓名:吴东平
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430204&ksmx=吴东平
# {'准考证': '018622430204', '姓名': '吴东平', '中国近现代史纲要': '90', 'JAVA程序设计': '88', '人工智能导论': '100', '网络安全技术': '89', '英语（二）': '62', '马克思主义基本原理概论': '85', '软件工程': '99', '计算机组成原理': '100', 'C++程序设计（实践）': '76'}
# =======================================================================================================================================
# 准考证号:018622430203,姓名:魏成戌
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430203&ksmx=魏成戌
# {'准考证': '018622430203', '姓名': '魏成戌', '中国近现代史纲要': '72', 'JAVA程序设计': '77', '人工智能导论': '76', '网络安全技术': '82', '英语（二）': '69', '马克思主义基本原理概论': '70', '软件工程': '95', '计算机组成原理': '73', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430202,姓名:曹嘉杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430202&ksmx=曹嘉杰
# {'准考证': '018622430202', '姓名': '曹嘉杰', '英语（二）': '56', '中国近现代史纲要': '83', 'JAVA程序设计': '85', '人工智能导论': '81', '网络安全技术': '87', '马克思主义基本原理概论': '67', '软件工程': '96', '计算机组成原理': '95', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430201,姓名:李天尚
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430201&ksmx=李天尚
# {'准考证': '018622430201', '姓名': '李天尚', '英语（二）': '39', '中国近现代史纲要': '78', 'JAVA程序设计': '77', '人工智能导论': '74', '网络安全技术': '79', '马克思主义基本原理概论': '68', '软件工程': '92', '计算机组成原理': '94', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430200,姓名:穆怀然
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430200&ksmx=穆怀然
# {'准考证': '018622430200', '姓名': '穆怀然', '英语（二）': '56', '中国近现代史纲要': '80', 'JAVA程序设计': '89', '人工智能导论': '99', '网络安全技术': '84', '马克思主义基本原理概论': '69', '软件工程': '99', '计算机组成原理': '91', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430199,姓名:黄洵
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430199&ksmx=黄洵
# {'准考证': '018622430199', '姓名': '黄洵', '英语（二）': '49', '中国近现代史纲要': '83', 'JAVA程序设计': '80', '人工智能导论': '91', '网络安全技术': '78', '马克思主义基本原理概论': '76', '软件工程': '89', '计算机组成原理': '97', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430198,姓名:毛杜劼
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430198&ksmx=毛杜劼
# {'准考证': '018622430198', '姓名': '毛杜劼', '英语（二）': '48', '中国近现代史纲要': '73', 'JAVA程序设计': '66', '人工智能导论': '96', '网络安全技术': '79', '马克思主义基本原理概论': '65', '软件工程': '97', '计算机组成原理': '79', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430197,姓名:昌彤童
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430197&ksmx=昌彤童
# {'准考证': '018622430197', '姓名': '昌彤童', '中国近现代史纲要': '77', 'JAVA程序设计': '83', '人工智能导论': '92', '网络安全技术': '84', '英语（二）': '64', '马克思主义基本原理概论': '73', '软件工程': '98', '计算机组成原理': '99', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430196,姓名:李倩
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430196&ksmx=李倩
# {'准考证': '018622430196', '姓名': '李倩', '英语（二）': '31', '中国近现代史纲要': '76', '马克思主义基本原理概论': '52', 'JAVA程序设计': '63', '人工智能导论': '77', '网络安全技术': '79', '软件工程': '86', '计算机组成原理': '60', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430195,姓名:高欣雨
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430195&ksmx=高欣雨
# {'准考证': '018622430195', '姓名': '高欣雨', '英语（二）': '49', '中国近现代史纲要': '78', '软件工程': '100', 'JAVA程序设计': '78', '人工智能导论': '85', '网络安全技术': '85', '马克思主义基本原理概论': '62', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430194,姓名:丁阳
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430194&ksmx=丁阳
# {'准考证': '018622430194', '姓名': '丁阳', '英语（二）': '免考', '中国近现代史纲要': '75', 'JAVA程序设计': '68', '人工智能导论': '88', '网络安全技术': '85', '马克思主义基本原理概论': '74', '软件工程': '99', '计算机组成原理': '85', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430193,姓名:周瀛川
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430193&ksmx=周瀛川
# {'准考证': '018622430193', '姓名': '周瀛川', '英语（二）': '51', '中国近现代史纲要': '81', 'JAVA程序设计': '72', '人工智能导论': '78', '网络安全技术': '85', '马克思主义基本原理概论': '70', '软件工程': '88', '计算机组成原理': '64', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430192,姓名:姜孟廷
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430192&ksmx=姜孟廷
# {'准考证': '018622430192', '姓名': '姜孟廷', '中国近现代史纲要': '83', 'JAVA程序设计': '82', '人工智能导论': '83', '网络安全技术': '80', '英语（二）': '61', '马克思主义基本原理概论': '73', '软件工程': '99', '计算机组成原理': '86', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430191,姓名:鹿泽正
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430191&ksmx=鹿泽正
# {'准考证': '018622430191', '姓名': '鹿泽正', '英语（二）': '42', '中国近现代史纲要': '75', 'JAVA程序设计': '70', '人工智能导论': '70', '网络安全技术': '82', '马克思主义基本原理概论': '66', '软件工程': '98', '计算机组成原理': '83', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430190,姓名:胡嵩
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430190&ksmx=胡嵩
# {'准考证': '018622430190', '姓名': '胡嵩', '英语（二）': '66', '中国近现代史纲要': '86', 'JAVA程序设计': '83', '人工智能导论': '86', '网络安全技术': '85', '马克思主义基本原理概论': '77', '软件工程': '92', '计算机组成原理': '100', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430189,姓名:刘明威
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430189&ksmx=刘明威
# {'准考证': '018622430189', '姓名': '刘明威', '英语（二）': '59', '中国近现代史纲要': '85', 'JAVA程序设计': '68', '人工智能导论': '88', '网络安全技术': '81', '马克思主义基本原理概论': '76', '软件工程': '87', '计算机组成原理': '86', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430188,姓名:尤祺
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430188&ksmx=尤祺
# {'准考证': '018622430188', '姓名': '尤祺', '英语（二）': '49', '中国近现代史纲要': '77', 'JAVA程序设计': '75', '人工智能导论': '82', '网络安全技术': '78', '马克思主义基本原理概论': '70', '软件工程': '91', '计算机组成原理': '95', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430187,姓名:吴章宇
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430187&ksmx=吴章宇
# {'准考证': '018622430187', '姓名': '吴章宇', '英语（二）': '免考', '中国近现代史纲要': '80', 'JAVA程序设计': '75', '人工智能导论': '94', '网络安全技术': '87', '马克思主义基本原理概论': '78', '软件工程': '89', '计算机组成原理': '96', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430186,姓名:马旌翔
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430186&ksmx=马旌翔
# {'准考证': '018622430186', '姓名': '马旌翔', '英语（二）': '49', '中国近现代史纲要': '84', 'JAVA程序设计': '69', '人工智能导论': '76', '网络安全技术': '83', '马克思主义基本原理概论': '62', '软件工程': '96', '计算机组成原理': '66', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430185,姓名:赵威
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430185&ksmx=赵威
# {'准考证': '018622430185', '姓名': '赵威', '英语（二）': '65', '中国近现代史纲要': '83', 'JAVA程序设计': '77', '人工智能导论': '95', '网络安全技术': '80', '马克思主义基本原理概论': '80', '软件工程': '93', '计算机组成原理': '93', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430184,姓名:李奕宣
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430184&ksmx=李奕宣
# {'准考证': '018622430184', '姓名': '李奕宣', '英语（二）': '免考', '中国近现代史纲要': '83', 'JAVA程序设计': '80', '人工智能导论': '91', '网络安全技术': '85', '马克思主义基本原理概论': '77', '软件工程': '99', '计算机组成原理': '99', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430183,姓名:王湧钦
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430183&ksmx=王湧钦
# {'准考证': '018622430183', '姓名': '王湧钦', '英语（二）': '64', '中国近现代史纲要': '79', 'JAVA程序设计': '81', '人工智能导论': '86', '网络安全技术': '80', '马克思主义基本原理概论': '66', '软件工程': '92', '计算机组成原理': '88', 'C++程序设计（实践）': '78'}
# =======================================================================================================================================
# 准考证号:018622430182,姓名:牛硕
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430182&ksmx=牛硕
# {'准考证': '018622430182', '姓名': '牛硕', '英语（二）': '32', '中国近现代史纲要': '78', 'JAVA程序设计': '72', '人工智能导论': '82', '网络安全技术': '82', '马克思主义基本原理概论': '73', '软件工程': '93', '计算机组成原理': '91', 'C++程序设计（实践）': '76'}
# =======================================================================================================================================
# 准考证号:018622430181,姓名:刘琳
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430181&ksmx=刘琳
# {'准考证': '018622430181', '姓名': '刘琳', '英语（二）': '54', '中国近现代史纲要': '78', 'JAVA程序设计': '77', '人工智能导论': '82', '网络安全技术': '82', '马克思主义基本原理概论': '66', '软件工程': '99', '计算机组成原理': '89', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430180,姓名:钱依晴
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430180&ksmx=钱依晴
# {'准考证': '018622430180', '姓名': '钱依晴', '英语（二）': '55', '中国近现代史纲要': '80', 'JAVA程序设计': '72', '人工智能导论': '75', '网络安全技术': '84', '马克思主义基本原理概论': '71', '软件工程': '99', '计算机组成原理': '73', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430179,姓名:戴启明
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430179&ksmx=戴启明
# {'准考证': '018622430179', '姓名': '戴启明', '英语（二）': '免考', '中国近现代史纲要': '70', 'JAVA程序设计': '61', '人工智能导论': '69', '网络安全技术': '81', '马克思主义基本原理概论': '70', '软件工程': '89', '计算机组成原理': '78', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430178,姓名:肖诗佳
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430178&ksmx=肖诗佳
# {'准考证': '018622430178', '姓名': '肖诗佳', '英语（二）': '56', '中国近现代史纲要': '82', 'JAVA程序设计': '86', '人工智能导论': '96', '网络安全技术': '85', '马克思主义基本原理概论': '70', '软件工程': '99', '计算机组成原理': '84', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430177,姓名:潘久海
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430177&ksmx=潘久海
# {'准考证': '018622430177', '姓名': '潘久海', '英语（二）': '69', '中国近现代史纲要': '78', 'JAVA程序设计': '82', '人工智能导论': '80', '网络安全技术': '79', '马克思主义基本原理概论': '76', '软件工程': '91', '计算机组成原理': '66', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430176,姓名:商荣珂
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430176&ksmx=商荣珂
# {'准考证': '018622430176', '姓名': '商荣珂', '英语（二）': '56', '中国近现代史纲要': '76', 'JAVA程序设计': '87', '人工智能导论': '83', '网络安全技术': '89', '马克思主义基本原理概论': '82', '软件工程': '99', '计算机组成原理': '91', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430175,姓名:纪力源
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430175&ksmx=纪力源
# {'准考证': '018622430175', '姓名': '纪力源', '英语（二）': '免考', '中国近现代史纲要': '87', '马克思主义基本原理概论': '74', 'JAVA程序设计': '80', '人工智能导论': '89', '网络安全技术': '81', '软件工程': '99', '计算机组成原理': '89', 'C++程序设计（实践）': '76'}
# =======================================================================================================================================
# 准考证号:018622430174,姓名:童延伟
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430174&ksmx=童延伟
# {'准考证': '018622430174', '姓名': '童延伟', '英语（二）': '53', '中国近现代史纲要': '80', 'JAVA程序设计': '72', '人工智能导论': '76', '网络安全技术': '80', '马克思主义基本原理概论': '72', '软件工程': '90', '计算机组成原理': '66', 'C++程序设计（实践）': '95'}
# =======================================================================================================================================
# 准考证号:018622430173,姓名:周力
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430173&ksmx=周力
# {'准考证': '018622430173', '姓名': '周力', '英语（二）': '51', '中国近现代史纲要': '80', 'JAVA程序设计': '57', '人工智能导论': '82', '网络安全技术': '84', '马克思主义基本原理概论': '70', '软件工程': '97', '计算机组成原理': '85', 'C++程序设计（实践）': '74'}
# =======================================================================================================================================
# 准考证号:018622430172,姓名:朱鑫莹
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430172&ksmx=朱鑫莹
# {'准考证': '018622430172', '姓名': '朱鑫莹', '英语（二）': '免考', '中国近现代史纲要': '83', '软件工程': '99', 'JAVA程序设计': '72', '人工智能导论': '84', '网络安全技术': '83', '马克思主义基本原理概论': '61', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430171,姓名:王晓虎
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430171&ksmx=王晓虎
# {'准考证': '018622430171', '姓名': '王晓虎', '英语（二）': '51', '中国近现代史纲要': '78', 'JAVA程序设计': '77', '人工智能导论': '87', '网络安全技术': '85', '马克思主义基本原理概论': '65', '软件工程': '96', '计算机组成原理': '78', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430170,姓名:朱敏羽
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430170&ksmx=朱敏羽
# {'准考证': '018622430170', '姓名': '朱敏羽', '中国近现代史纲要': '80', 'JAVA程序设计': '77', '人工智能导论': '97', '网络安全技术': '85', '英语（二）': '65', '马克思主义基本原理概论': '81', '软件工程': '93', '计算机组成原理': '100', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430169,姓名:张奕恺
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430169&ksmx=张奕恺
# {'准考证': '018622430169', '姓名': '张奕恺', '中国近现代史纲要': '77', 'JAVA程序设计': '78', '人工智能导论': '81', '网络安全技术': '79', '英语（二）': '61', '马克思主义基本原理概论': '75', '软件工程': '98', '计算机组成原理': '94', 'C++程序设计（实践）': '78'}
# =======================================================================================================================================
# 准考证号:018622430168,姓名:何旭东
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430168&ksmx=何旭东
# {'准考证': '018622430168', '姓名': '何旭东', '中国近现代史纲要': '80', 'JAVA程序设计': '57', '人工智能导论': '74', '网络安全技术': '75', '英语（二）': '66', '马克思主义基本原理概论': '76', '软件工程': '92', '计算机组成原理': '95', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430167,姓名:周嘉懿
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430167&ksmx=周嘉懿
# {'准考证': '018622430167', '姓名': '周嘉懿', '英语（二）': '49', '中国近现代史纲要': '80', 'JAVA程序设计': '74', '人工智能导论': '89', '网络安全技术': '81', '马克思主义基本原理概论': '71', '软件工程': '92', '计算机组成原理': '60', 'C++程序设计（实践）': '72'}
# =======================================================================================================================================
# 准考证号:018622430166,姓名:崔硕
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430166&ksmx=崔硕
# {'准考证': '018622430166', '姓名': '崔硕', '英语（二）': '41', '中国近现代史纲要': '85', 'JAVA程序设计': '62', '人工智能导论': '75', '网络安全技术': '73', '马克思主义基本原理概论': '68', '软件工程': '88', '计算机组成原理': '85', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430165,姓名:汤国平
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430165&ksmx=汤国平
# {'准考证': '018622430165', '姓名': '汤国平', '英语（二）': '40', '中国近现代史纲要': '77', 'JAVA程序设计': '73', '人工智能导论': '73', '网络安全技术': '85', '马克思主义基本原理概论': '72', '软件工程': '92', '计算机组成原理': '83', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430164,姓名:杨忠信
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430164&ksmx=杨忠信
# {'准考证': '018622430164', '姓名': '杨忠信', '中国近现代史纲要': '85', 'JAVA程序设计': '78', '人工智能导论': '87', '网络安全技术': '76', '英语（二）': '75', '马克思主义基本原理概论': '78', '软件工程': '99', '计算机组成原理': '95', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430163,姓名:袁添
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430163&ksmx=袁添
# {'准考证': '018622430163', '姓名': '袁添', '英语（二）': '78', '中国近现代史纲要': '74', 'JAVA程序设计': '58', '人工智能导论': '72', '网络安全技术': '77', '马克思主义基本原理概论': '65', '软件工程': '92', '计算机组成原理': '60', 'C++程序设计（实践）': '74'}
# =======================================================================================================================================
# 准考证号:018622430162,姓名:刘士义
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430162&ksmx=刘士义
# {'准考证': '018622430162', '姓名': '刘士义', '英语（二）': '58', '中国近现代史纲要': '85', 'JAVA程序设计': '82', '人工智能导论': '93', '网络安全技术': '86', '马克思主义基本原理概论': '68', '软件工程': '93', '计算机组成原理': '98', 'C++程序设计（实践）': '85'}
# =======================================================================================================================================
# 准考证号:018622430161,姓名:孙昊岩
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430161&ksmx=孙昊岩
# {'准考证': '018622430161', '姓名': '孙昊岩', '英语（二）': '30', '中国近现代史纲要': '82', 'JAVA程序设计': '76', '人工智能导论': '81', '网络安全技术': '82', '马克思主义基本原理概论': '63', '软件工程': '98', '计算机组成原理': '77', 'C++程序设计（实践）': '92'}
# =======================================================================================================================================
# 准考证号:018622430160,姓名:卢峙奇
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430160&ksmx=卢峙奇
# {'准考证': '018622430160', '姓名': '卢峙奇', '中国近现代史纲要': '77', 'JAVA程序设计': '65', '人工智能导论': '79', '网络安全技术': '81', '英语（二）': '62', '马克思主义基本原理概论': '75', '软件工程': '97', '计算机组成原理': '72', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430159,姓名:孙乙宸
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430159&ksmx=孙乙宸
# {'准考证': '018622430159', '姓名': '孙乙宸', '英语（二）': '44', '中国近现代史纲要': '80', 'JAVA程序设计': '77', '人工智能导论': '66', '网络安全技术': '78', '马克思主义基本原理概论': '70', '软件工程': '87', '计算机组成原理': '84', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430158,姓名:盛杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430158&ksmx=盛杰
# {'准考证': '018622430158', '姓名': '盛杰', '英语（二）': '75', '中国近现代史纲要': '72', 'JAVA程序设计': '66', '人工智能导论': '68', '网络安全技术': '79', '马克思主义基本原理概论': '60', '软件工程': '92', '计算机组成原理': '72', 'C++程序设计（实践）': '95'}
# =======================================================================================================================================
# 准考证号:018622430157,姓名:魏斌
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430157&ksmx=魏斌
# {'准考证': '018622430157', '姓名': '魏斌', '英语（二）': '28', 'JAVA程序设计': '52', '人工智能导论': '64', '网络安全技术': '80', '马克思主义基本原理概论': '63', '中国近现代史纲要': '76', '软件工程': '95', '计算机组成原理': '69', 'C++程序设计（实践）': '76'}
# =======================================================================================================================================
# 准考证号:018622430156,姓名:吴德捷
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430156&ksmx=吴德捷
# {'准考证': '018622430156', '姓名': '吴德捷', '中国近现代史纲要': '87', 'JAVA程序设计': '89', '人工智能导论': '90', '网络安全技术': '85', '英语（二）': '60', '马克思主义基本原理概论': '86', '软件工程': '93', '计算机组成原理': '96', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430155,姓名:马永健
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430155&ksmx=马永健
# {'准考证': '018622430155', '姓名': '马永健', '中国近现代史纲要': '80', 'JAVA程序设计': '85', '人工智能导论': '81', '网络安全技术': '85', '英语（二）': '60', '马克思主义基本原理概论': '83', '软件工程': '97', '计算机组成原理': '87', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430154,姓名:徐正新
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430154&ksmx=徐正新
# {'准考证': '018622430154', '姓名': '徐正新', '英语（二）': '57', 'JAVA程序设计': '56', '人工智能导论': '62', '网络安全技术': '83', '马克思主义基本原理概论': '74', '中国近现代史纲要': '79', '软件工程': '91', '计算机组成原理': '85', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430153,姓名:耿渊博
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430153&ksmx=耿渊博
# {'准考证': '018622430153', '姓名': '耿渊博', '英语（二）': '20', '中国近现代史纲要': '78', 'JAVA程序设计': '78', '人工智能导论': '76', '网络安全技术': '85', '马克思主义基本原理概论': '60', '软件工程': '96', '计算机组成原理': '82', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430152,姓名:丁龙
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430152&ksmx=丁龙
# {'准考证': '018622430152', '姓名': '丁龙', '中国近现代史纲要': '80', 'JAVA程序设计': '71', '人工智能导论': '64', '网络安全技术': '74', '英语（二）': '28', '马克思主义基本原理概论': '70', '软件工程': '94', '计算机组成原理': '60', 'C++程序设计（实践）': '78'}
# =======================================================================================================================================
# 准考证号:018622430151,姓名:豆航
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430151&ksmx=豆航
# {'准考证': '018622430151', '姓名': '豆航', '中国近现代史纲要': '71', 'JAVA程序设计': '62', '人工智能导论': '70', '网络安全技术': '73', '英语（二）': '62', '马克思主义基本原理概论': '62', '软件工程': '89', '计算机组成原理': '76', 'C++程序设计（实践）': '74'}
# =======================================================================================================================================
# 准考证号:018622430150,姓名:钱诚
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430150&ksmx=钱诚
# {'准考证': '018622430150', '姓名': '钱诚', '英语（二）': '免考', '中国近现代史纲要': '76', 'JAVA程序设计': '66', '人工智能导论': '82', '网络安全技术': '82', '马克思主义基本原理概论': '73', '软件工程': '90', '计算机组成原理': '77', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430149,姓名:姜丰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430149&ksmx=姜丰
# ...
# =======================================================================================================================================
# 准考证号:018622430090,姓名:许天乐
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430090&ksmx=许天乐
# {'准考证': '018622430090', '姓名': '许天乐', '中国近现代史纲要': '77', 'JAVA程序设计': '71', '人工智能导论': '96', '网络安全技术': '83', '英语（二）': '67', '马克思主义基本原理概论': '73', '软件工程': '97', '计算机组成原理': '84', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430089,姓名:李文杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430089&ksmx=李文杰
# {'准考证': '018622430089', '姓名': '李文杰', '英语（二）': '26', '中国近现代史纲要': '82', '计算机组成原理': '55', 'JAVA程序设计': '79', '人工智能导论': '94', '网络安全技术': '79', '马克思主义基本原理概论': '67', '软件工程': '88', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430088,姓名:丁浩然
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430088&ksmx=丁浩然
# {'准考证': '018622430088', '姓名': '丁浩然', '英语（二）': '31', '中国近现代史纲要': '81', '软件工程': '99', 'JAVA程序设计': '84', '人工智能导论': '81', '网络安全技术': '85', '马克思主义基本原理概论': '78', 'C++程序设计（实践）': '74'}
# =======================================================================================================================================
# 准考证号:018622430087,姓名:杨文杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430087&ksmx=杨文杰
# {'准考证': '018622430087', '姓名': '杨文杰', '英语（二）': '47', '中国近现代史纲要': '73', 'JAVA程序设计': '91', '人工智能导论': '83', '网络安全技术': '85', '马克思主义基本原理概论': '76', '软件工程': '94', '计算机组成原理': '94', 'C++程序设计（实践）': '92'}
# =======================================================================================================================================
# 准考证号:018622430086,姓名:赵玉慧
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430086&ksmx=赵玉慧
# {'准考证': '018622430086', '姓名': '赵玉慧', '英语（二）': '50', '中国近现代史纲要': '73', 'JAVA程序设计': '86', '人工智能导论': '84', '网络安全技术': '84', '马克思主义基本原理概论': '60', '软件工程': '96', '计算机组成原理': '78', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430085,姓名:叶进城
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430085&ksmx=叶进城
# {'准考证': '018622430085', '姓名': '叶进城', '英语（二）': '41', '中国近现代史纲要': '69', '计算机组成原理': '51', 'JAVA程序设计': '67', '人工智能导论': '79', '网络安全技术': '77', '马克思主义基本原理概论': '70', '软件工程': '94', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430084,姓名:张欣欣
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430084&ksmx=张欣欣
# {'准考证': '018622430084', '姓名': '张欣欣', '英语（二）': '66', 'JAVA程序设计': '54', '人工智能导论': '65', '网络安全技术': '80', '马克思主义基本原理概论': '76', '中国近现代史纲要': '79', '软件工程': '92', '计算机组成原理': '87', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430083,姓名:秦正和
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430083&ksmx=秦正和
# {'准考证': '018622430083', '姓名': '秦正和', '英语（二）': '38', '中国近现代史纲要': '80', 'JAVA程序设计': '58', '人工智能导论': '70', '网络安全技术': '74', '马克思主义基本原理概论': '61', '软件工程': '79', '计算机组成原理': '71', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430082,姓名:刘益江
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430082&ksmx=刘益江
# {'准考证': '018622430082', '姓名': '刘益江', '英语（二）': '36', '中国近现代史纲要': '78', '马克思主义基本原理概论': '50', 'JAVA程序设计': '35', '人工智能导论': '57', '网络安全技术': '82', '软件工程': '88', '计算机组成原理': '60', 'C++程序设计（实践）': '98'}
# =======================================================================================================================================
# 准考证号:018622430081,姓名:徐佳蕾
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430081&ksmx=徐佳蕾
# {'准考证': '018622430081', '姓名': '徐佳蕾', '英语（二）': '47', '中国近现代史纲要': '77', 'JAVA程序设计': '85', '人工智能导论': '94', '网络安全技术': '83', '马克思主义基本原理概论': '76', '软件工程': '98', '计算机组成原理': '97', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430080,姓名:陶杰
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430080&ksmx=陶杰
# {'准考证': '018622430080', '姓名': '陶杰', '英语（二）': '56', '中国近现代史纲要': '82', 'JAVA程序设计': '67', '人工智能导论': '80', '网络安全技术': '82', '马克思主义基本原理概论': '72', '软件工程': '91', '计算机组成原理': '75', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430079,姓名:夏雨婕
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430079&ksmx=夏雨婕
# {'准考证': '018622430079', '姓名': '夏雨婕', '英语（二）': '50', '中国近现代史纲要': '84', 'JAVA程序设计': '84', '人工智能导论': '94', '网络安全技术': '83', '马克思主义基本原理概论': '79', '软件工程': '99', '计算机组成原理': '93', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430078,姓名:孟小龙
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430078&ksmx=孟小龙
# {'准考证': '018622430078', '姓名': '孟小龙', '英语（二）': '33', '中国近现代史纲要': '76', '软件工程': '83', 'JAVA程序设计': '74', '人工智能导论': '74', '网络安全技术': '72', '马克思主义基本原理概论': '63', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430077,姓名:孙雨婷
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430077&ksmx=孙雨婷
# {'准考证': '018622430077', '姓名': '孙雨婷', '英语（二）': '49', '中国近现代史纲要': '76', 'JAVA程序设计': '79', '人工智能导论': '95', '网络安全技术': '81', '马克思主义基本原理概论': '80', '软件工程': '99', '计算机组成原理': '94', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430076,姓名:吴强
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430076&ksmx=吴强
# {'准考证': '018622430076', '姓名': '吴强', '中国近现代史纲要': '76', 'JAVA程序设计': '79', '人工智能导论': '74', '网络安全技术': '81', '英语（二）': '69', '马克思主义基本原理概论': '71', '软件工程': '96', '计算机组成原理': '89', 'C++程序设计（实践）': '78'}
# =======================================================================================================================================
# 准考证号:018622430075,姓名:马景景
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430075&ksmx=马景景
# {'准考证': '018622430075', '姓名': '马景景', '英语（二）': '45', 'JAVA程序设计': '85', '人工智能导论': '71', '网络安全技术': '83', '马克思主义基本原理概论': '75', '中国近现代史纲要': '70', '软件工程': '94', '计算机组成原理': '89', 'C++程序设计（实践）': '78'}
# =======================================================================================================================================
# 准考证号:018622430074,姓名:孙士博
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430074&ksmx=孙士博
# {'准考证': '018622430074', '姓名': '孙士博', '中国近现代史纲要': '77', 'JAVA程序设计': '87', '人工智能导论': '88', '网络安全技术': '84', '英语（二）': '63', '马克思主义基本原理概论': '74', '软件工程': '96', '计算机组成原理': '86', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430073,姓名:倪毅超
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430073&ksmx=倪毅超
# {'准考证': '018622430073', '姓名': '倪毅超', '中国近现代史纲要': '89', 'JAVA程序设计': '87', '人工智能导论': '93', '网络安全技术': '88', '英语（二）': '69', '马克思主义基本原理概论': '82', '软件工程': '98', '计算机组成原理': '89', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430072,姓名:鲍怡扬
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430072&ksmx=鲍怡扬
# {'准考证': '018622430072', '姓名': '鲍怡扬', '英语（二）': '56', '中国近现代史纲要': '80', '计算机组成原理': '38', 'JAVA程序设计': '67', '人工智能导论': '74', '网络安全技术': '83', '马克思主义基本原理概论': '69', '软件工程': '91', 'C++程序设计（实践）': '85'}
# =======================================================================================================================================
# 准考证号:018622430071,姓名:邵疏桐
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430071&ksmx=邵疏桐
# {'准考证': '018622430071', '姓名': '邵疏桐', '中国近现代史纲要': '83', 'JAVA程序设计': '68', '人工智能导论': '82', '网络安全技术': '85', '英语（二）': '67', '马克思主义基本原理概论': '87', '软件工程': '99', '计算机组成原理': '91', 'C++程序设计（实践）': '80'}
# =======================================================================================================================================
# 准考证号:018622430070,姓名:李敬
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430070&ksmx=李敬
# {'准考证': '018622430070', '姓名': '李敬', '中国近现代史纲要': '76', '软件工程': '89', 'JAVA程序设计': '83', '人工智能导论': '89', '网络安全技术': '85', '英语（二）': '61', '马克思主义基本原理概论': '72', 'C++程序设计（实践）': '72'}
# =======================================================================================================================================
# 准考证号:018622430069,姓名:何璐
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430069&ksmx=何璐
# {'准考证': '018622430069', '姓名': '何璐', '英语（二）': '55', '中国近现代史纲要': '79', 'JAVA程序设计': '90', '人工智能导论': '98', '网络安全技术': '87', '马克思主义基本原理概论': '73', '软件工程': '98', '计算机组成原理': '66', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430068,姓名:管雨欣
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430068&ksmx=管雨欣
# {'准考证': '018622430068', '姓名': '管雨欣', '中国近现代史纲要': '85', 'JAVA程序设计': '90', '人工智能导论': '100', '网络安全技术': '89', '英语（二）': '60', '马克思主义基本原理概论': '84', '软件工程': '91', '计算机组成原理': '88', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430067,姓名:朱铭凡
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430067&ksmx=朱铭凡
# {'准考证': '018622430067', '姓名': '朱铭凡', 'JAVA程序设计': '84', '人工智能导论': '96', '网络安全技术': '85', '英语（二）': '56', '马克思主义基本原理概论': '84', '中国近现代史纲要': '87', '软件工程': '99', '计算机组成原理': '98', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430066,姓名:朱晨晨
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430066&ksmx=朱晨晨
# {'准考证': '018622430066', '姓名': '朱晨晨', '英语（二）': '40', '中国近现代史纲要': '81', 'JAVA程序设计': '59', '人工智能导论': '68', '网络安全技术': '79', '马克思主义基本原理概论': '72', '软件工程': '84', '计算机组成原理': '67', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430065,姓名:季益迈
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430065&ksmx=季益迈
# {'准考证': '018622430065', '姓名': '季益迈', '中国近现代史纲要': '84', 'JAVA程序设计': '88', '人工智能导论': '85', '网络安全技术': '85', '英语（二）': '68', '马克思主义基本原理概论': '80', '软件工程': '85', '计算机组成原理': '88', 'C++程序设计（实践）': '78'}
# =======================================================================================================================================
# 准考证号:018622430064,姓名:张成
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430064&ksmx=张成
# {'准考证': '018622430064', '姓名': '张成', '英语（二）': '35', '中国近现代史纲要': '78', 'JAVA程序设计': '75', '人工智能导论': '77', '网络安全技术': '82', '马克思主义基本原理概论': '68', '软件工程': '98', '计算机组成原理': '75', 'C++程序设计（实践）': '75'}
# =======================================================================================================================================
# 准考证号:018622430063,姓名:赵凯
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430063&ksmx=赵凯
# {'准考证': '018622430063', '姓名': '赵凯', '英语（二）': '45', '中国近现代史纲要': '64', 'JAVA程序设计': '85', '人工智能导论': '91', '网络安全技术': '82', '马克思主义基本原理概论': '73', '软件工程': '94', '计算机组成原理': '83', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430062,姓名:罗瑞
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430062&ksmx=罗瑞
# {'准考证': '018622430062', '姓名': '罗瑞', '英语（二）': '70', '中国近现代史纲要': '71', '计算机组成原理': '25', 'JAVA程序设计': '85', '人工智能导论': '86', '网络安全技术': '81', '马克思主义基本原理概论': '85', '软件工程': '70', 'C++程序设计（实践）': '70'}
# =======================================================================================================================================
# 准考证号:018622430061,姓名:虞志辉
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430061&ksmx=虞志辉
# {'准考证': '018622430061', '姓名': '虞志辉', '英语（二）': '74', '中国近现代史纲要': '79', 'JAVA程序设计': '86', '人工智能导论': '90', '网络安全技术': '83', '马克思主义基本原理概论': '81', '软件工程': '83', '计算机组成原理': '89', 'C++程序设计（实践）': '76'}
# =======================================================================================================================================
# 准考证号:018622430060,姓名:王毛豆
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430060&ksmx=王毛豆
# {'准考证': '018622430060', '姓名': '王毛豆', '英语（二）': '28', '中国近现代史纲要': '81', '软件工程': '98', 'JAVA程序设计': '72', '人工智能导论': '95', '网络安全技术': '86', '马克思主义基本原理概论': '81', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================
# 准考证号:018622430059,姓名:张淇
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430059&ksmx=张淇
# {'准考证': '018622430059', '姓名': '张淇', '中国近现代史纲要': '85', 'JAVA程序设计': '86', '人工智能导论': '93', '网络安全技术': '83', '英语（二）': '72', '马克思主义基本原理概论': '80', '软件工程': '99', '计算机组成原理': '100', 'C++程序设计（实践）': '86'}
# =======================================================================================================================================
# 准考证号:018622430058,姓名:万雅雯
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430058&ksmx=万雅雯
# {'准考证': '018622430058', '姓名': '万雅雯', '英语（二）': '免考', 'JAVA程序设计': '93', '人工智能导论': '97', '网络安全技术': '91', '马克思主义基本原理概论': '85', '中国近现代史纲要': '88', '软件工程': '92', '计算机组成原理': '100', 'C++程序设计（实践）': '88'}
# =======================================================================================================================================
# 准考证号:018622430057,姓名:章宇航
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430057&ksmx=章宇航
# {'准考证': '018622430057', '姓名': '章宇航', '中国近现代史纲要': '83', 'JAVA程序设计': '85', '人工智能导论': '85', '网络安全技术': '82', '英语（二）': '60', '马克思主义基本原理概论': '74', '软件工程': '99', '计算机组成原理': '90', 'C++程序设计（实践）': '90'}
# =======================================================================================================================================
# 准考证号:018622430056,姓名:王妍
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430056&ksmx=王妍
# {'准考证': '018622430056', '姓名': '王妍', '英语（二）': '54', '中国近现代史纲要': '83', 'JAVA程序设计': '89', '人工智能导论': '98', '网络安全技术': '90', '马克思主义基本原理概论': '78', '软件工程': '92', '计算机组成原理': '99', 'C++程序设计（实践）': '84'}
# =======================================================================================================================================
# 准考证号:018622430055,姓名:杨嘉欣
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430055&ksmx=杨嘉欣
# {'准考证': '018622430055', '姓名': '杨嘉欣', '中国近现代史纲要': '75', '软件工程': '92', 'JAVA程序设计': '81', '人工智能导论': '78', '网络安全技术': '81', '英语（二）': '67', '马克思主义基本原理概论': '75', 'C++程序设计（实践）': '82'}
# =======================================================================================================================================

# %%
df = pd.DataFrame(scores_list)
df
# Out:
#               准考证   姓名 JAVA程序设计 人工智能导论 网络安全技术 英语（二） 马克思主义基本原理概论 软件工程 计算机组成原理  \
# 0    018622430856  王颢杰       59     58     80    26          48   90      62
# 1    018622430823  罗瑞清       57     70     66    10          66   72      28
# 2    018622430822  王晨依       77     88     87    44          68   93      95
# 3    018622430820   李昊       69     76     85    60          74   93      70
# 4    018622430819  黄佳义       74     84     84    37          73   94      91
# ..            ...  ...      ...    ...    ...   ...         ...  ...     ...
# 200  018622430059   张淇       86     93     83    72          80   99     100
# 201  018622430058  万雅雯       93     97     91    免考          85   92     100
# 202  018622430057  章宇航       85     85     82    60          74   99      90
# 203  018622430056   王妍       89     98     90    54          78   92      99
# 204  018622430055  杨嘉欣       81     78     81    67          75   92     NaN
#
#     C++程序设计（实践） 中国近现代史纲要
# 0            70      NaN
# 1            70       68
# 2            88       74
# 3            80       61
# 4            78       81
# ..          ...      ...
# 200          86       85
# 201          88       88
# 202          90       83
# 203          84       83
# 204          82       75
#
# [205 rows x 11 columns]

# %%
print(scores_list)
# Out:
# [{'准考证': '018622430856', '姓名': '王颢杰', 'JAVA程序设计': '59', '人工智能导论': '58', '网络安全技术': '80', '英语（二）': '26', '马克思主义基本原理概论': '48', '软件工程': '90', '计算机组成原理': '62', 'C++程序设计（实践）': '70'}, {'准考证': '018622430823', '姓名': '罗瑞清', '计算机组成原理': '28', 'JAVA程序设计': '57', '人工智能导论': '70', '网络安全技术': '66', '英语（二）': '10', '马克思主义基本原理概论': '66', '软件工程': '72', 'C++程序设计（实践）': '70'}, {'准考证': '018622430822', '姓名': '王晨依', 'JAVA程序设计': '77', '人工智能导论': '88', '网络安全技术': '87', '英语（二）': '44', '马克思主义基本原理概论': '68', '软件工程': '93', '计算机组成原理': '95', 'C++程序设计（实践）': '88'}, {'准考证': '018622430820', '姓名': '李昊', 'JAVA程序设计': '69', '人工智能导论': '76', '网络安全技术': '85', '英语（二）': '60', '马克思主义基本原理概论': '74', '中国近现代史纲要': '61', '软件工程': '93', '计算机组成原理': '70', 'C++程序设计（实践）': '80'}, {'准考证': '018622430819', '姓名': '黄佳义', 'JAVA程序设计': '74', '人工智能导论': '84', '网络安全技术': '84', '英语（二）': '37', '马克思主义基本原理概论': '73', '软件工程': '94', '计算机组成原理': '91', 'C++程序设计（实践）': '78'}, {'准考证': '018622430818', '姓名': '邵凯旋', 'JAVA程序设计': '70', '人工智能导论': '75', '网络安全技术': '76', '英语（二）': '37', '马克思主义基本原理概论': '68', '软件工程': '90', '计算机组成原理': '83', 'C++程序设计（实践）': '88'}, {'准考证': '018622430817', '姓名': '米玛措姆', '软件工程': '78', 'JAVA程序设计': '84', '人工智能导论': '87', '网络安全技术': '80', '英语（二）': '38', '马克思主义基本原理概论': '56', 'C++程序设计（实践）': '70'}, {'准考证': '018622430816', '姓名': '沈飞', 'JAVA程序设计': '88', '人工智能导论': '90', '网络安全技术': '81', '英语（二）': '42', '马克思主义基本原理概论': '72', '软件工程': '97', '计算机组成原理': '99', 'C++程序设计（实践）': '90'}, {'准考证': '018622430815', '姓名': '宋京鹏', 'JAVA程序设计': '78', '人工智能导论': '78', '网络安全技术': '87', '英语（二）': '60', '马克思主义基本原理概论': '82', '软件工程': '98', '计算机组成原理': '99', 'C++程序设计（实践）': '88'}, {'准考证': '018622430814', '姓名': '段文龙', '软件工程': '94', 'JAVA程序设计': '80', '人工智能导论': '75', '网络安全技术': '84', '英语（二）': '31', '马克思主义基本原理概论': '68', 'C++程序设计（实践）': '70'}, {'准考证': '018622430812', '姓名': '张锐', '软件工程': '100', 'JAVA程序设计': '91', '人工智能导论': '90', '网络安全技术': '85', '英语（二）': '51', '马克思主义基本原理概论': '79', 'C++程序设计（实践）': '70'}, {'准考证': '018622430248', '姓名': '丁玥玥', 'JAVA程序设计': '49', '人工智能导论': '65', '网络安全技术': '78', '英语（二）': '50', '马克思主义基本原理概论': '71', '软件工程': '91', '计算机组成原理': '81', 'C++程序设计（实践）': '93'}, {'准考证': '018622430247', '姓名': '刘雅轩', 'JAVA程序设计': '86', '人工智能导论': '96', '网络安全技术': '87', '英语（二）': '43', '马克思主义基本原理概论': '77', '软件工程': '99', '计算机组成原理': '93', 'C++程序设计（实践）': '88'}, {'准考证': '018622430246', '姓名': '刘泓妙', '英语（二）': '61', 'JAVA程序设计': '84', '人工智能导论': '79', '网络安全技术': '83', '马克思主义基本原理概论': '73', '软件工程': '99', '计算机组成原理': '100', 'C++程序设计（实践）': '86'}, {'准考证': '018622430245', '姓名': '孙羽婷', '英语（二）': '免考', 'JAVA程序设计': '79', '人工智能导论': '93', '网络安全技术': '83', '马克思主义基本原理概论': '82', '软件工程': '99', '计算机组成原理': '96', 'C++程序设计（实践）': '94'}, {'准考证': '018622430244', '姓名': '许晨昕', '英语（二）': '免考', 'JAVA程序设计': '87', '人工智能导论': '95', '网络安全技术': '77', '马克思主义基本原理概论': '55', '软件工程': '88', '计算机组成原理': '85', 'C++程序设计（实践）': '88'}, {'准考证': '018622430243', '姓名': '赵婧雯', 'JAVA程序设计': '88', '人工智能导论': '100', '网络安全技术': '88', '英语（二）': '50', '马克思主义基本原理概论': '68', '软件工程': '93', '计算机组成原理': '94', 'C++程序设计（实践）': '80'}, {'准考证': '018622430242', '姓名': '余强', '英语（二）': '75', 'JAVA程序设计': '82', '人工智能导论': '93', '网络安全技术': '80', '马克思主义基本原理概论': '68', '软件工程': '98', '计算机组成原理': '93', 'C++程序设计（实践）': '78'}, {'准考证': '018622430241', '姓名': '孙若雨', 'JAVA程序设计': '91', '人工智能导论': '92', '网络安全技术': '86', '英语（二）': '52', '马克思主义基本原理概论': '76', '软件工程': '98', '计算机组成原理': '92', 'C++程序设计（实践）': '82'}, {'准考证': '018622430240', '姓名': '陈晨', 'JAVA程序设计': '65', '人工智能导论': '85', '网络安全技术': '85', '英语（二）': '48', '马克思主义基本原理概论': '72', '软件工程': '91', '计算机组成原理': '95', 'C++程序设计（实践）': '88'}, {'准考证': '018622430239', '姓名': '詹成康', 'JAVA程序设计': '83', '人工智能导论': '100', '网络安全技术': '90', '英语（二）': '60', '马克思主义基本原理概论': '74', '软件工程': '99', '计算机组成原理': '100', 'C++程序设计（实践）': '72'}, {'准考证': '018622430238', '姓名': '李徽', 'JAVA程序设计': '83', '人工智能导论': '83', '网络安全技术': '85', '英语（二）': '44', '马克思主义基本原理概论': '70', '软件工程': '94', '计算机组成原理': '97', 'C++程序设计（实践）': '86'}, {'准考证': '018622430237', '姓名': '万晨鹏', '英语（二）': '免考', 'JAVA程序设计': '78', '人工智能导论': '78', '网络安全技术': '82', '马克思主义基本原理概论': '72', '软件工程': '86', '计算机组成原理': '86', 'C++程序 ...

# %% [markdown]
# ### 保存文件

# %%
df = pd.DataFrame(scores_list)

# %%
# 将免考替换为90
df["英语（二）"] = df["英语（二）"].replace({"免考":-1})
df
# Out:
#               准考证   姓名 JAVA程序设计 人工智能导论 网络安全技术 英语（二） 马克思主义基本原理概论 软件工程 计算机组成原理  \
# 0    018622430856  王颢杰       59     58     80    26          48   90      62
# 1    018622430823  罗瑞清       57     70     66    10          66   72      28
# 2    018622430822  王晨依       77     88     87    44          68   93      95
# 3    018622430820   李昊       69     76     85    60          74   93      70
# 4    018622430819  黄佳义       74     84     84    37          73   94      91
# ..            ...  ...      ...    ...    ...   ...         ...  ...     ...
# 200  018622430059   张淇       86     93     83    72          80   99     100
# 201  018622430058  万雅雯       93     97     91    -1          85   92     100
# 202  018622430057  章宇航       85     85     82    60          74   99      90
# 203  018622430056   王妍       89     98     90    54          78   92      99
# 204  018622430055  杨嘉欣       81     78     81    67          75   92     NaN
#
#     C++程序设计（实践） 中国近现代史纲要
# 0            70      NaN
# 1            70      NaN
# 2            88      NaN
# 3            80       61
# 4            78      NaN
# ..          ...      ...
# 200          86      NaN
# 201          88       88
# 202          90      NaN
# 203          84      NaN
# 204          82      NaN
#
# [205 rows x 11 columns]

# %%
df['英语（二）'] = df['英语（二）'].astype(float)  #转为整数型
df[df["英语（二）"]>=60]
# Out:
#               准考证   姓名 JAVA程序设计 人工智能导论 网络安全技术  英语（二） 马克思主义基本原理概论 软件工程 计算机组成原理  \
# 3    018622430820   李昊       69     76     85   60.0          74   93      70
# 8    018622430815  宋京鹏       78     78     87   60.0          82   98      99
# 13   018622430246  刘泓妙       84     79     83   61.0          73   99     100
# 17   018622430242   余强       82     93     80   75.0          68   98      93
# 20   018622430239  詹成康       83    100     90   60.0          74   99     100
# ..            ...  ...      ...    ...    ...    ...         ...  ...     ...
# 197  018622430062   罗瑞       85     86     81   70.0          85   70      25
# 198  018622430061  虞志辉       86     90     83   74.0          81   83      89
# 200  018622430059   张淇       86     93     83   72.0          80   99     100
# 202  018622430057  章宇航       85     85     82   60.0          74   99      90
# 204  018622430055  杨嘉欣       81     78     81   67.0          75   92     NaN
#
#     C++程序设计（实践） 中国近现代史纲要
# 3            80       61
# 8            88      NaN
# 13           86      NaN
# 17           78      NaN
# 20           72      NaN
# ..          ...      ...
# 197          70      NaN
# 198          76      NaN
# 200          86      NaN
# 202          90      NaN
# 204          82      NaN
#
# [61 rows x 11 columns]

# %%
df.to_csv("自考成绩.csv",index=False)

# %% [markdown]
# ## 读取Excel文件

# %%
import pandas as pd
path = "D:\\SOFT\\code\\zkz.xlsx"
df = pd.read_excel(path,dtype=str)

df
# Out:
#     Unnamed: 0   姓名          准考证号
# 0            1  王颢杰  018622430856
# 1            2  罗瑞清  018622430823
# 2            3  王晨依  018622430822
# 3            4   李昊  018622430820
# 4            5  黄佳义  018622430819
# ..         ...  ...           ...
# 200        201   张淇  018622430059
# 201        202  万雅雯  018622430058
# 202        203  章宇航  018622430057
# 203        204   王妍  018622430056
# 204        205  杨嘉欣  018622430055
#
# [205 rows x 3 columns]

# %%
students = df[["姓名","准考证号"]]
students
# Out:
#       姓名          准考证号
# 0    王颢杰  018622430856
# 1    罗瑞清  018622430823
# 2    王晨依  018622430822
# 3     李昊  018622430820
# 4    黄佳义  018622430819
# ..   ...           ...
# 200   张淇  018622430059
# 201  万雅雯  018622430058
# 202  章宇航  018622430057
# 203   王妍  018622430056
# 204  杨嘉欣  018622430055
#
# [205 rows x 2 columns]

# %%
import requests
from bs4 import BeautifulSoup

def getDatas(id_,name):
    print("准考证号:{},姓名:{}".format(id_,name))
    url = "https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh={}&ksmx={}".format(id_,name)
    print(url)
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
    }
    resp = requests.get(url,headers=headers)
    html = resp.content.decode('utf-8')
    soup = BeautifulSoup(html, "html.parser") 
    table = soup.find_all(name='td')
    j = 1
    datas = []
    scores = {}
    for i in table:
        if i.string != "理论课程":
            datas.append(i.string)
    for i in range(2,len(datas)):
        if datas[i]!=None:
            if len(datas[i])>1 and len(datas[i])<=3:
                if eval(datas[i])<=100 or eval(datas[i])>=0:
#                     print(datas[i-1],":",datas[i])
                    scores[datas[i-1]] = datas[i]
                    
            if "免" in datas[i] and datas[i-1]!=None:
#                 print(datas[i-1],":","免考")
                scores[datas[i-1]] = "免考"
    return scores
    print(scores)
    print("=======================================================================================================================================")

# %% [markdown]
# ## 最终程序

# %%
import pandas as pd
import requests,time
from bs4 import BeautifulSoup

# 读取xlsx
def read_file():
    path = "D:\SOFT\code\zkz.xlsx"
    df = pd.read_excel(path,dtype=str)
    # 获取需要的 姓名、准考证  信息数据
    students = df[["姓名","准考证号"]]
    return students
    

def getDatas(id_,name):
    print("正在爬取 {} 学生的成绩".format(name))
    url = "https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh={}&ksmx={}".format(id_,name)
    print(url)
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
    }
    resp = requests.get(url,headers=headers)
    html = resp.content.decode('utf-8')
    soup = BeautifulSoup(html, "html.parser") 
    table = soup.find_all(name='td')
    j = 1
    datas = []
    scores = {}
    for i in table:
        if i.string != "理论课程":
            datas.append(i.string)
    for i in range(2,len(datas)):
        if datas[i]!=None:
            if len(datas[i])>1 and len(datas[i])<=3:
                if eval(datas[i])<=100 or eval(datas[i])>=0:
#                     print(datas[i-1],":",datas[i])
                    scores[datas[i-1]] = datas[i]
                    
            if "免" in datas[i] and datas[i-1]!=None:
#                 print(datas[i-1],":","免考")
                scores[datas[i-1]] = "免考"
    return scores
    

    
# 将数据进行简单的预处理
def process_data(students):
    scores_list = []
    for i in range(0,len(students)):
        scores_dic = getDatas(a[i][1],a[i][0])
        scores_list.append(scores_dic)
    return scores_list
        
 # 将数据保存为csv文件 
def write_file(scores_list):
    df = pd.DataFrame(scores_list)
    df.to_csv("自考成绩.csv",index=False)
    print("文件保存成功!")
    

if __name__=="__main__":
    # 读取文件
    students = read_file()
    # 爬取数据 并处理
    scores_list = process_data(students)
    print(scores_list)
# Out:
# 正在爬取 王颢杰 学生的成绩
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=罗瑞清&ksmx=王颢杰
# 正在爬取 018622430856 学生的成绩
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430823&ksmx=018622430856
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\SOFT\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\SOFT\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\SOFT\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 64
#      62 students = read_file()
#      63 # 爬取数据 并处理
# ---> 64 scores_list = process_data(students)
#      65 print(scores_list)
#
# Cell In[20], line 49, in process_data(students)
#      47 scores_list = []
#      48 for i in range(0,len(students)):
# ---> 49     scores_dic = getDatas(a[i][1],a[i][0])
#      50     scores_list.append(scores_dic)
#      51 return scores_list
#
# File D:\SOFT\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File D:\SOFT\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 2

# %%
import requests
from bs4 import BeautifulSoup

def getDatas(id_,name):
    print("准考证号:{},姓名:{}".format(id_,name))
    url = "https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh={}&ksmx={}".format(id_,name)
    print(url)
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
    }
    resp = requests.get(url,headers=headers)
    html = resp.content.decode('utf-8')
    soup = BeautifulSoup(html, "html.parser") 
    table = soup.find_all(name='td')
    j = 1
    datas = []
    s = []
    for i in table:
        datas.append(str(i.string))
    # print(datas)
    for i in range(0,len(datas)):
#         if len(datas[i])<=3:
    #         if eval(datas[i])<=100 or eval(datas[i])>=0 or datas[i]=="免考":
#             print(datas[i-1],":",datas[i])
        
#             s.append((datas[i-1],datas[i]));
        print(datas[i])
#     return s;

# %%
getDatas(a[1][4],a[0][4])
# Out:
# 准考证号:018622430819,姓名:黄佳义
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430819&ksmx=黄佳义

# %%
scores_list = []
for i in range(3,len(students)-200):
#     scores_dic = getDatas(a[1][i],a[0][i])
    scores_list.append(getDatas(a[1][i],a[0][i]))
scores_list
# Out:
# 准考证号:018622430820,姓名:李昊
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430820&ksmx=李昊
# 准考证号:018622430819,姓名:黄佳义
# https://sdata.jseea.cn/tpl_front/score/allScoreList.html/?zkzh=018622430819&ksmx=黄佳义
# [[('JAVA程序设计', '69'),
#   ('人工智能导论', '76'),
#   ('网络安全技术', '85'),
#   ('英语（二）', '60'),
#   ('马克思主义基本原理概论', '74'),
#   ('中国近现代史纲要', '61'),
#   ('软件工程', '93'),
#   ('计算机组成原理', '70'),
#   ('C++程序设计（实践）', '80')],
#  [('英语（二）', '43'),
#   ('中国近现代史纲要', '81'),
#   ('JAVA程序设计', '74'),
#   ('人工智能导论', '84'),
#   ('网络安全技术', '84'),
#   ('英语（二）', '37'),
#   ('马克思主义基本原理概论', '73'),
#   ('软件工程', '94'),
#   ('计算机组成原理', '91'),
#   ('C++程序设计（实践）', '78')]]

# %%
for i in scores_list:
    print(i)
# Out:
# [('JAVA程序设计', '69'), ('人工智能导论', '76'), ('网络安全技术', '85'), ('英语（二）', '60'), ('马克思主义基本原理概论', '74'), ('中国近现代史纲要', '61'), ('软件工程', '93'), ('计算机组成原理', '70'), ('C++程序设计（实践）', '80')]
# [('英语（二）', '43'), ('中国近现代史纲要', '81'), ('JAVA程序设计', '74'), ('人工智能导论', '84'), ('网络安全技术', '84'), ('英语（二）', '37'), ('马克思主义基本原理概论', '73'), ('软件工程', '94'), ('计算机组成原理', '91'), ('C++程序设计（实践）', '78')]
