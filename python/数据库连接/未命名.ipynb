# %%
from sqlalchemy import create_engine
import pandas as pd

MYSQL_HOST = '124.222.117.184'
MYSQL_PORT = '33060'
MYSQL_USER = 'root'
MYSQL_PASSWORD = 'root@root'
MYSQL_DB = 'scoolresult'

engine = create_engine('mysql+pymysql://%s:%s@%s:%s/%s?charset=utf8'
                           % (MYSQL_USER, MYSQL_PASSWORD, MYSQL_HOST, MYSQL_PORT, MYSQL_DB))

# %%
import pandas as pd

path = "/Users/liu/code/python/scores.csv"
df = pd.read_csv(path)

# %%
df
# Out:
#              准考证   姓名  JAVA程序设计  人工智能导论  ...  软件工程  计算机组成原理  C++程序设计（实践）  中国近现代史纲要
# 0    18622430856  王颢杰      59.0    58.0  ...  90.0     62.0         70.0       NaN
# 1    18622430823  罗瑞清      57.0    70.0  ...  72.0     28.0         70.0       NaN
# 2    18622430822  王晨依      77.0    88.0  ...  93.0     95.0         88.0       NaN
# 3    18622430820   李昊      69.0    76.0  ...  93.0     70.0         80.0      61.0
# 4    18622430819  黄佳义      74.0    84.0  ...  94.0     91.0         78.0       NaN
# ..           ...  ...       ...     ...  ...   ...      ...          ...       ...
# 200  18622430059   张淇      86.0    93.0  ...  99.0    100.0         86.0       NaN
# 201  18622430058  万雅雯      93.0    97.0  ...  92.0    100.0         88.0      88.0
# 202  18622430057  章宇航      85.0    85.0  ...  99.0     90.0         90.0       NaN
# 203  18622430056   王妍      89.0    98.0  ...  92.0     99.0         84.0       NaN
# ...

# %%
df.to_sql("socre",con=engine)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:644, in Connection.connect(self, sock)
#     643 try:
# --> 644     sock = socket.create_connection(
#     645         (self.host, self.port), self.connect_timeout, **kwargs
#     646     )
#     647     break
#
# File ~/anaconda3/lib/python3.11/socket.py:827, in create_connection(address, timeout, source_address, all_errors)
#     826 exceptions = []
# --> 827 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     828     af, socktype, proto, canonname, sa = res
#
# File ~/anaconda3/lib/python3.11/socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# ...

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@124.222.117.184/{db}"
                               .format(user="root",
                                       pw="root@root",
                                       db="test"))
df.to_sql(con=engine, name='socre')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:644, in Connection.connect(self, sock)
#     643 try:
# --> 644     sock = socket.create_connection(
#     645         (self.host, self.port), self.connect_timeout, **kwargs
#     646     )
#     647     break
#
# File ~/anaconda3/lib/python3.11/socket.py:827, in create_connection(address, timeout, source_address, all_errors)
#     826 exceptions = []
# --> 827 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     828     af, socktype, proto, canonname, sa = res
#
# File ~/anaconda3/lib/python3.11/socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# ...
